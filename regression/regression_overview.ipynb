# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Let us create a dataset containing house prices (y) corresponding to the house sizes (x). 
# Let us only create 2 examples in the training set

X_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

print(f"X_train: {X_train}")
print(f"y_train: {y_train}")
# Out:
# X_train: [1. 2.]
# y_train: [300. 500.]

# %%
# m denotes the number of examples 
print(f"X_train.shape: {X_train.shape}")
m = X_train.shape[0]
print(f"Number of training examples: {m}")
# Out:
# X_train.shape: (2,)
# Number of training examples: 2

# %%
# We will use x_i and y_i to denote ith training example
i = 1
x_i = X_train[i]
y_i = y_train[i]

print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(1), y^(1)) = (2.0, 500.0)

# %%
# Plot the two datapoints in the training set

plt.scatter(X_train, y_train, marker='x', c='b')
plt.title('Housing Prices')
plt.xlabel('House Size (1000 sqft)')
plt.ylabel('House Price ($1000)')
plt.grid()
plt.show()

# %% [markdown]
# the model function for linear regression (which is a function that maps from `x` to `y`) is represented as
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot. <br/> <br/> <br/> <br/> <br/>
# Let's try to get a better intuition for this through the code blocks below. Let's start with $w = 100$ and $b = 100$.
# **Note: You can come back to this cell to adjust the model's w and b parameters**

# %%
w = 100
b = 100
i = 1

# Compute fw,b(x_i) 

def f(x, w, b):
    return w * x + b


x_i = X_train[i]
f_xi = f(x_i, w, b)
print(f"fw,b(x^{i}) = {f_xi}")
# Out:
# fw,b(x^1) = 300.0

# %%
# Compute fx,b(x_i) for each i belonging to {0, 1}

def compute_model_output(x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)

    for i in range(m):
        f_wb[i] = w * x[i] + b
    
    return f_wb

print(f"Outputs: {compute_model_output(X_train, w, b)}")
# Out:
# Outputs: [200. 300.]

# %%
# Plot our predictions 
predictions = compute_model_output(X_train, w, b)
plt.plot(X_train, predictions, c='r', label='Predictions')
plt.scatter(X_train, y_train, c='b', label='Actual Outputs')

plt.xlabel('House Size (1000sqft)')
plt.ylabel('House Price ($1000)')
plt.grid()
plt.legend()
plt.show()

# %%
# Perfect parameters are the following:

w = 200
b = 100

predictions = compute_model_output(X_train, w, b)
plt.plot(X_train, predictions, c='r', label='Predictions')
plt.scatter(X_train, y_train, c='b', label='Actual Outputs')

plt.xlabel('House Size (1000sqft)')
plt.ylabel('House Price ($1000)')
plt.grid()
plt.legend()
plt.show()

# %%
# Now that we have the 'learned' model, we can use it to make predictions on the unseen data
x_input = np.array([1.7, 1.5]) 
y_pred = compute_model_output(x_input, w, b)
print(f"Predictions: {y_pred}")
# Out:
# Predictions: [440. 400.]
